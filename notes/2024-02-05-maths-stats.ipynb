# %%
answer = 2 + (3**2) - (2*(4+((4*2)**2))/((6/3)*2))

# %%
from sympy import symbols
from sympy.plotting import plot

# %%
x = symbols('x')
f = 2*x + 1
plot(f)

# %%
x = symbols('x')
f = x**3+15*x+300
plot(f)

# %%
def root(x, dom):
    return x**(1/dom)

root(64, 3)
# Out:
# 4093
